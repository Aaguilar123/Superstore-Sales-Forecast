# %% [markdown]
# # Phase 3: Individual Modeling - XGBoost Regressor
# **Author:** Renju (Member 3)
#
# ## 1. Model Justification
# *Add Harvard-referenced theoretical justification for using tree-based ensemble learning to capture nonlinear retail demand behavior here.*

# %% [markdown]
# ## 2. Environment Setup
# Importing required libraries and configuring the working directory (supports both Local and Google Colab execution).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import os
from sklearn.metrics import mean_absolute_error, mean_squared_error

# If running in Colab, mount Drive and change working directory
try:
    from google.colab import drive
    drive.mount('/content/drive')

    # Update this path to point to your project's 'Code' folder in Drive
    project_code_path = '/content/drive/MyDrive/Colab Notebooks/Nargis Attila/Code'
    os.chdir(project_code_path)
    print("Running in Google Colab. Working directory set to:", os.getcwd())
except ImportError:
    # Not in Colab, keep default local working directory
    print("Running locally. Working directory remains unchanged.")
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Running in Google Colab. Working directory set to: /content/drive/MyDrive/Colab Notebooks/Nargis Attila/Code

# %% [markdown]
# ## 3. Data Loading
# Loading the shared cleaned datasets using relative paths.

# %%
# Load datasets using identical relative paths for both Local and Colab
df_daily = pd.read_csv('../Data/clean_daily_ready.csv', parse_dates=['date'], index_col='date')
df_monthly = pd.read_csv('../Data/clean_monthly_ready.csv', parse_dates=['date'], index_col='date')

print("Daily Data Shape:", df_daily.shape)
print("Monthly Data Shape:", df_monthly.shape)
# Out:
# Daily Data Shape: (1458, 4)
# Monthly Data Shape: (48, 5)

# %% [markdown]
# ## 4. Feature Engineering
# Constructing lagged features, rolling means, and calendar-based predictors.

# %%
# Example Feature Engineering Structure
def create_features(df):
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['month'] = df.index.month
    df['quarter'] = df.index.quarter
    df['year'] = df.index.year
    return df

df_daily_features = create_features(df_daily)
df_monthly_features = create_features(df_monthly)

# %% [markdown]
# ## 5. Train-Test Split (Strict Chronological)

# %%
train_daily = df_daily_features.loc['2015-01-01':'2017-12-31']
test_daily = df_daily_features.loc['2018-01-01':'2018-12-31']

print("Daily Train Set:", train_daily.shape)
print("Daily Test Set:", test_daily.shape)
# Out:
# Daily Train Set: (1094, 8)
# Daily Test Set: (364, 8)

# %% [markdown]
# ## 6. Baseline Models
# Implementation of Naïve Forecast and Historical Mean.

# %%
# Code for Naïve and Historical Mean baselines goes here

# %% [markdown]
# ## 7. XGBoost Modeling & Optimization
# Tuning `max_depth`, `learning_rate`, `n_estimators`, and subsampling parameters.

# %%
# Code for XGBoost Regressor training and tuning goes here

# %% [markdown]
# ## 8. Discussion & Reflection
# *Assess XGBoost’s ability to model nonlinear demand spikes and promotional volatility.*
